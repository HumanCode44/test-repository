# %% [markdown]
# <a href="https://colab.research.google.com/github/HumanCode44/test-repository/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bio_path= '/content/drive/MyDrive/Cohort 10 Capstone/data/527d0a83e4b0850ea0518326.csv'

bio_one = pd.read_csv(bio_path)

# %%
bio_one.head()
# Out:
#   GAP_code                      common_name             scientific_name  \
# 0   aABSAx          Austin Blind Salamander       Eurycea waterlooensis
# 1   aACSSx  Atlantic Coast Slimy Salamander     Plethodon chlorobryonis
# 2   aADSAx    Apalachicola Dusky Salamander  Desmognathus apalachicolae
# 3   aAGTOx                    Amargosa Toad            Anaxyrus nelsoni
# 4   aAMBUx                American Bullfrog     Lithobates catesbeianus
#
#    start_date  end_date publication_date  \
# 0        2008      2016          2018-07
# 1        2008      2013          2018-07
# 2        2008      2013          2018-07
# 3        2008      2013          2018-07
# 4        2008      2015          2018-07
#
#                                             citation place_keywords  \
# 0  U.S. Geological Survey - Gap Analysis Program,...  United States
# 1  U.S. Geological Survey - Gap Analysis Program,...  United States
# 2  U.S. Geological Survey - Gap Analysis Program,...  United States
# ...

# %%
bio_one.shape
# Out:
# (1719, 20)
